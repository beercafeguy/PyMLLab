# %% [markdown]
# <a href="https://colab.research.google.com/github/beercafeguy/PyMLLab/blob/master/assignments/Seaborn_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Que 1:** Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# **Ans**
#
# 1. Line Plot : Used to plot a simple two variable function as line
# 2. Scatter Plot : used to see the relationship between two variables
# 3. Box Plot : Used to see the distribution of data in one variable
# 4. Cat Plot : cat plot is used to see the distribution of data on categorical columns
# 5. Histogram : histogram is used to see the frequency distribution of a variable

# %% [markdown]
# **Que 2:** Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
# "timepoint" and y = "signal" for different events and regions.

# %%
import seaborn as sns
fmri = sns.load_dataset('fmri')
sns.lineplot(x="timepoint",y="signal",data=fmri,hue='event',ci=None)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",y="signal",data=fmri,hue='region',ci=None)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# **Que 3:** Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
# 'pclass', y = 'age' and y = 'fare'.

# %%
titanic = sns.load_dataset('titanic')
sns.set(rc={'figure.figsize':(20,12)})
sns.boxplot(data=titanic, x="pclass", y="age")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=titanic, x="pclass", y="fare")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='fare'>

# %% [markdown]
# **Que 4:** Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
# parameter for the 'cut' column of the diamonds dataset.

# %%
diamonds = sns.load_dataset('diamonds')
sns.set(rc={'figure.figsize':(20,12)})
sns.histplot(data=diamonds, x="price",hue='cut')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# **Que 5:** Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
# of the iris dataset.

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris,hue='species')

# %% [markdown]
# **Que 6:** Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flights = sns.load_dataset('flights').pivot("year", "month", "passengers")
flights
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(flights)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>
