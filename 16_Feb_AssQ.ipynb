# %% [markdown]
# <a href="https://colab.research.google.com/github/beercafeguy/PyMLLab/blob/master/16_Feb_AssQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q1.** What is a database? Differentiate between SQL and NoSQL databases.

# %% [markdown]
# **ANS**
#
# **Database **: Database is a software system which is used to store the data in an organized fashion on computer disks. It provides different constructs for managing the data, options for access management and reliable ways of managing data.
#
# **Difference between SQL and NoSQL databases**
#
# SQL databases are the systems where data can be stores and accessed using a standard query language called SQL. All the SQL databases supports some form of SQL for there operations. Example : MySQL, SQL Server, Oracle 11G, DB2 etc
#
# <br>
#
# NoSQL (Not only SQL) databases are databses are designed for specific neeeds where RDBMS systems might not be best fit like specific scale and latency needs. Mostly these systems do not support SQL in plain form. Each NoSQL databases has its own API/language for managing and accessing data. Example of such databases are MongoDB, Cassandra etc.

# %% [markdown]
# **Q2.** What is DDL? Explain why CREATE, DROP, ALTER, and TRUNCATE are used with an example.

# %% [markdown]
# **DDL:**
#
# Data Definition language (DDL) are the set of SQL commands which are used for creating and managing RDBMS storage constructs like databases and tables.
#
# <br>CREATE: Used to create the object (table/database)
# <br>DROP: Used to drop the object from database (delete full structure and data)
# <br>ALTER: Change the structure of the object like adding columns in table.
# <br>TRUNCATE: Delete all the data from table but keep the structure.

# %% [markdown]
# ![Create_Table.png](data:image/png;base64,...)

# %% [markdown]
# ![Drop_Table.png](data:image/png;base64,...)

# %% [markdown]
# ![Alter_Table.png](data:image/png;base64,...)

# %% [markdown]
# ![Truncate_Table.png](data:image/png;base64,...)

# %% [markdown]
# Q3. What is DML? Explain INSERT, UPDATE, and DELETE with an example.

# %% [markdown]
# DML (Data Manipulation Language) used to manage the data insertion and updation part of SQL

# %% [markdown]
# ![DML.png](data:image/png;base64,...)

# %% [markdown]
# **Q4.** What is DQL? Explain SELECT with an example.

# %% [markdown]
# DQL (Data suery language) is a part of SQL which is used to access the data stored in database tables.
#
# ![DQL.png](data:image/png;base64,...)

# %% [markdown]
# Q5. Explain Primary Key and Foreign Key.

# %% [markdown]
#  Primary Key is a column in a RDBMS table which can be used to identify each record uniquely. It should only have unique values and it can't be null.
#
#  Foreign Key is afield in a table which is used to identyfy promary key of another table. This is used to manage relations in SQL tables.

# %% [markdown]
# ![keys.png](data:image/png;base64,...)

# %% [markdown]
# ![keys1.png](data:image/png;base64,...)

# %% [markdown]
# Here the code broke because we don't have the entry of the given department id (101) in department table. Once we fix this, insert query will run.
# ![keys2.png](data:image/png;base64,...)
